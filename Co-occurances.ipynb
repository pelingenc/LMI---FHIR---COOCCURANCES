# %% [markdown]
# ## LIBRARY

# %%
import os
import re
import pandas as pd
import tkinter as tk
from tkinter import ttk
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import matplotlib.pyplot as plt
import networkx as nx
from collections import defaultdict
import math
from collections import Counter
import mplcursors
import matplotlib as mpl
import textwrap

# %% [markdown]
# ## READING FHIR

# %%
directory = 'C:/Users/begon/synthea/output/deneme1'

pattern = re.compile(r'(\"resourceType\": \"(Patient|Encounter|Condition|Observation|Procedure|Medication)\")')

classes = ['Patient', 'Encounter', 'Condition', 'Observation', 'Procedure', 'Medication']

current_resource_type = None
new_resource_type = None
resource_type = None
current_id = None
new_id = None
current_references = []
current_codes = []
display = []
current_patient_id = None
previous_display = None 
previous_code = None 
code_starts_with_LA = False  # Flag to track if the current code starts with "LA"


data = {'ResourceType': [], 'ID': [], 'References': [], 'Codes': [], 'PatientID': []}

counts = {resource_type: 1 for resource_type in classes}

INIT = False

for filename in os.listdir(directory):
    if filename.endswith('.json'):
        with open(os.path.join(directory, filename), 'r', encoding='utf-8') as f:
            for line in f:
                match = pattern.search(line)
                if '"resourceType": "' in line and not match:
                    resource_type = line.split('"')[3]
                    INIT = False
                if match:
                    if match.group(2) in classes:
                        new_resource_type = match.group(2)
                        INIT = True
                        next_line = next(f, None)
                        if next_line and '"id": "' in next_line:
                            new_id = next_line.split('"id": "')[1].split('"')[0]
                if current_resource_type == new_resource_type and '"reference": "urn:uuid:' in line and INIT:
                    reference = line.split(':')[3].split('"')[0]
                    current_references.append(reference)    
                    
                if current_resource_type == new_resource_type and '"code": "' in line and INIT:
                    code = line.split('"code": "')[1].split('"')[0]
                    if any(char.isdigit() for char in code):
                        #print(current_patient_id, code)
                        next_line = next(f, None)
                        if next_line and '"display": "' in next_line:
                            if code.startswith("LA") and previous_display is not None:                    
                                display = previous_display + ': ' + next_line.split('"display": "')[1].split('"')[0]
                                code = previous_code
                                current_codes[-1] = (previous_code, display)
                                #current_codes.append((previous_code, display))
                                #print('(code, display)', (current_patient_id, code, display))
                                code_starts_with_LA = True
                            else:
                                display = next_line.split('"display": "')[1].split('"')[0]
                                current_codes.append((code, display))
                                code_starts_with_LA = False
                                #print('(code, display)', (current_patient_id, code, display))
                        # Update previous display only if the code doesn't start withp "LA"
                        if not code_starts_with_LA:
                            previous_display = display
                            previous_code = code

                 
                if current_resource_type != new_resource_type  and INIT:
                    if current_resource_type and current_id:
                        data['ResourceType'].append(current_resource_type)
                        data['ID'].append(current_id)
                        if current_resource_type == 'Patient':
                            current_patient_id = current_id
                        data['References'].append(tuple(current_references))
                        data['Codes'].append(tuple(current_codes))
                        data['PatientID'].append(current_patient_id)
                        current_references = []
                        current_codes = []
                    current_resource_type = new_resource_type    
                    current_id = new_id

df = pd.DataFrame(data)
grouped = df.groupby('PatientID')
aggregated_data = grouped.sum()
aggregated_data.to_csv('C:/Users/begon/Desktop/LMI PROJECT/GIT-LMI/Patient1.csv')

# %% [markdown]
# ## DROP DOWN LIST

# %%
import pandas as pd

# Assuming df is your DataFrame
# Flatten the 'Codes' column
flattened_df = df.explode('Codes')

# Reset the index after exploding
flattened_df.reset_index(drop=True, inplace=True)

# Assuming flattened_df is your DataFrame after exploding the 'Codes' column

# Extract only the first item of each tuple in the 'Codes' column using list comprehension
options = set(code[0] for code in flattened_df['Codes'])


# Convert the set to a list if needed
options = list(options)

# Print the resulting list of options
print(options)
# Out:
# ['718-7', '2777-1', '5602001', '165829005', '1505002', '283545005', '11466000', '854252', '49765-1', '2021-4', '807283', '84478008', '410410006', '8867-4', '55822004', '306706006', '2746-6', '89204-2', '33959-8', '410538000', '122548005', '423315002', '267020005', '32167-9', '40055000', '751-8', '308335008', '92141-1', '714812005', '252482003', '418891003', '33367005', '2532-0', '2498-4', 'X9999-2', '1728805', '840544004', '128613002', '271737000', '2085-9', '18262-6', '82667-7', '312608009', '224295006', '855812', '2028-9', '2705-2', '305342007', '173160006', '169230002', '424132000', '306185001', '169762003', '6525002', '423475008', '260413007', '239873007', '1121000119107', '4548-4', '424441002', '88805009', '78275009', '76164006', '2157-6', '104326007', '25064002', '88021-1', '762952008', '762993000', '74006-8', '110467000', '132281000119108', '59557-9', '72514-3', '223484005', '20565-8', '104435004', '276409005', '85319-2', '314137006', '14736009', '5787-7', '12719002', '50849002', '365691004', '5770-3', '39848009', '63697000', '271280005', '68496003', '223470000', '73595000', '313191000', '68254000', '73438004', '703151001', '1116635', '2514-8', '75636-1', '82589-3', '57905-2', '303653007', '2069-3', '156073000', '39898005', '76501-6', '167277001', '16114001', '5778-6', '583214', '713-8', '1361048', '5797-6', '787-2', '6299-2', '1920-8', '74400008', '427419006', '710824005', '2123111', '386478007', '742-7', '27942005', '14804-9', '1975-2', '92138-7', '33762-6', '99999-4', '82808001', '195967001', '735029006', '9279-1', '44465007', '275778006', '866148006', '60234000', '444470001', '384709000', '162673000', '10480-2', '84100007', '87433001', '275978004', '99999-1', '1000126', '31676001', '443529005', '56799-0', '229064008', '19169002', '185349003', '770-8', '203082005', '269911007', '71425-3', '410770002', '5803-2', '403190006', '29303009', '43075005', '13945-1', '22523008', '3718001', '288086009', '698314001', '1736854', '183519002', '76504-0', '386661006', '60845006', '71493000', '1234995', '33737001', '266753000', '403191005', '252160004', '408512008', '8480-6', '305408004', '6095-4', '431855005', '5794-3', '58150001', '6844-5', '306316000', '398171003', '118001005', '42825003', '562366', '76690-7', '428251008', '453131000124105', '6106-9', '314138001', '76746007', '710839006', '165197003', '386516004', '167287002', '89579-7', '14627-4', '290045001', '260373001', '1736776', '91146-1', '25656009', '399261000', '271442007', '160903007', '167290008', '310861008', '399211009', '284551006', '183996000', '6833-8', '278860009', '32911000', '19926-5', '18946005', '8290005', '225158009', '422650009', '267036007', '1719286', '284549007', '6085-5', '74016001', '3094-0', '10828004', '448337001', '312617', '854235', '287664005', '167265006', '14768001', '54899-0', '171231001', '2744-1', '5821-4', '267253006', '6082-2', '196416002', '167297006', '94040-3', '183452005', '763302001', '1809104', '308646001', '390906007', '394701000', '20505-4', '94531-1', '99999-0', '71802-3', '90226004', '713106006', '30893008', '1571000087109', '93038-8', '6690-2', '38483-4', '363406005', '609496007', '85548006', '392091000', '69453-9', '25675004', '439708006', '399014008', '248595008', '59265000', '90781000119102', '770349000', '15777000', '305336008', '394712000', '38265-5', '542347', '23351008', '266919005', '8331-1', '171207006', '46240-8', '2106-3', '157141000119108', '401314000', '301882004', '75498004', '3016-3', '233678006', '268556000', '167288007', '167275009', '198440', '274474001', '167271000', '311791003', '180256009', '59408-5', '183478001', '5251000175109', '28163009', '442571000124108', '5902-2', '777-3', '65750-2', '385633008', '418824004', '1988-5', '93034-7', '9843-4', '281789004', '72892002', '37849005', '5802-4', '1796676', '34533-0', '2339-0', '6158-0', '127013003', '212033', '60027007', '80383-3', '14959-1', '99999-8', '307426000', '2703-7', '263102004', '99999-9', '21905-5', '55758-7', '4544-3', '261634002', '431857002', '2669 ...

# %% [markdown]
# ## OPTIONS BOTH CODE AND DISPLAY

# %%
import pandas as pd

flattened_df = df.explode('Codes')
flattened_df.reset_index(drop=True, inplace=True)
#codes = [code[0] for code in flattened_df['Codes']]
#displays = [display[1] for display in flattened_df['Codes']]
# Extract only the first item of each tuple in the 'Codes' column using list comprehension
codes = [code[0] for code in flattened_df['Codes']]

# Extract the second item (display) of each tuple in the 'Codes' column using list comprehension
displays = [display[1] for display in flattened_df['Codes']]

# Combine codes and displays into a single list of options
options_zip = {code: display for code, display in zip(codes, displays)}
options_zip
# Out:
# {'2106-3': 'White',
#  '2186-5': 'Not Hispanic or Latino',
#  '410620009': 'Well child visit (procedure)',
#  '314529007': 'Medication review due (situation)',
#  '8302-2': 'Body Height',
#  '72514-3': 'Pain severity - 0-10 verbal numeric rating [Score] - Reported',
#  '29463-7': 'Body Weight',
#  '39156-5': 'Body mass index (BMI) [Ratio]',
#  '59576-9': 'Body mass index (BMI) [Percentile] Per age and sex',
#  '85354-9': 'Blood pressure panel with all children optional',
#  '8462-4': 'Diastolic Blood Pressure',
#  '8480-6': 'Systolic Blood Pressure',
#  '8867-4': 'Heart rate',
#  '9279-1': 'Respiratory rate',
#  '6690-2': 'Leukocytes [#/volume] in Blood by Automated count',
#  '789-8': 'Erythrocytes [#/volume] in Blood by Automated count',
#  '718-7': 'Hemoglobin [Mass/volume] in Blood',
#  '4544-3': 'Hematocrit [Volume Fraction] of Blood by Automated count',
#  '787-2': 'MCV [Entitic volume] by Automated count',
#  '785-6': 'MCH [Entitic mass] by Automated count',
#  '786-4': 'MCHC [Mass/volume] by Automated count',
#  '21000-5': 'Erythrocyte distribution width [Entitic volume] by Automated count',
#  '777-3': 'Platelets [#/volume] in Blood by Automated count',
#  '32207-3': 'Platelet distribution width [Entitic volume] in Blood by Automated count',
#  '32623-1': 'Platelet mean volume [Entitic volume] in Blood by Automated count',
#  '72166-2': 'Tobacco smoking status',
#  '266919005': 'Never smoked tobacco (finding)',
#  '430193006': 'Medication Reconciliation (procedure)',
#  '185345009': 'Encounter for symptom',
#  '444814009': 'Viral sinusitis (disorder)',
#  '195662009': 'Acute viral pharyngitis (disorder)',
#  '8310-5': 'Body temperature',
#  '8331-1': 'Oral temperature',
#  '117015009': 'Throat culture (procedure)',
#  '70274-6': 'Generalized anxiety disorder 7 item (GAD-7) total score [Reported.PHQ]',
#  '89204-2': 'Patient Health Questionnaire-9: Modified for Teens total score [Reported.PHQ.Teen]',
#  '710841007': 'Assessment of anxiety (procedure)',
#  '171207006': 'Depression screening (procedure)',
#  '715252007': 'Depression screening using Patient Health Questionnaire Nine Item score (procedure)',
#  '428211000124100': 'Assessment of substance use (procedure)',
#  '868187001': 'Assessment using Car, Relax, Alone, Forget, Friends, Trouble Screening Test (procedure)',
#  '386516004': 'Anticipatory guidance (procedure)',
#  '33879002': 'Administration of vaccine to produce active immunity (procedure)',
#  '698314001': 'Consultation for treatment',
#  '389095005': 'Contraception care (regime/therapy)',
#  '160968000': 'Risk activity involvement (finding)',
#  '370995009': 'Health risks education (procedure)',
#  '43878008': 'Streptococcal sore throat (disorder)',
#  '2054-5': 'Black or African American',
#  '162673000': 'General examination of patient (procedure)',
#  '224299000': 'Received higher education (finding)',
#  '15777000': 'Prediabetes',
#  '162864005': 'Body mass index 30+ - obesity (finding)',
#  '266948004': 'Has a criminal record (finding)',
#  '185349003': 'Encounter for check up (procedure)',
#  '271737000': 'Anemia (disorder)',
#  '59621000': 'Essential hypertension (disorder)',
#  '237602007': 'Metabolic syndrome X (disorder)',
#  '414545008': 'Ischemic heart disease (disorder)',
#  '185347001': 'Encounter for problem',
#  '274531002': 'Abnormal findings diagnostic imaging heart+coronary circulat (finding)',
#  '423315002': 'Limited social contact (finding)',
#  '706893006': 'Victim of intimate partner abuse (finding)',
#  '422650009': 'Social isolation (finding)',
#  '239872002': 'Osteoarthritis of hip',
#  '160904001': 'Part-time employment (finding)',
#  '160903007': 'Full-time employment (finding)',
#  '73595000': 'Stress (finding)',
#  '4548-4': 'Hemoglobin A1c/Hemoglobin.total in Blood',
#  '2339-0': 'Glucose [Mass/volume] in Blood',
#  '6299-2': 'Urea nitrogen [Mass/volume] in Blood',
#  '38483-4': 'Creatinine [Mass/volume] in Blood',
#  '49765-1': 'Calcium [Mass/volume] in Blood',
#  '2947-0': 'Sodium [Moles/volume] in Blood',
#  '6298-4': 'Potassium [Moles/volume] in Blood',
#  '2069-3': 'Chloride [Moles/volume] in Blood',
#  '20565-8': 'Carbon dioxide, total [Moles/volume] in Blood',
#  '93025-5': "Protocol for Responding to and Assessing Patients' Assets, Risks, and Experiences [PRAPARE]",
#  '76501-6': 'Within the last year, have you been afraid of your partner or ex-partner?: No',
#  '93026-3': 'Do you feel physically and emotionally safe where you currently live?: Yes',
#  '93027-1': 'Are you a refugee?: No',
#  '93028-9': 'In the past year, have you spent more than 2 nights in a row in a jail, prison, detention center, or juvenile correctional facility?: No',
#  '93038-8': 'Stress level: Not at all',
#  '93029-7': 'How often do you see or talk to people that you care about and feel close to (For example: talking to friends on the phone, visiting friends or family, going to church or club meetings)?: 5 or more times a week',
#  '93030-5': 'Has lack of transportation kept you from medical appointments, meetings, work, or from getting things needed for daily living: No',
#  '93031-3': 'In the past year, have you or any family members you live with been unable to get any of the following when it was really needed?: I choose not to answer this question',
#  '63586-2': 'What was your best estimate of the total income of all family members from all sources, before taxes, in last year?',
#  '76437-3': 'Primary insurance: Medicare',
#  '67875-5': 'Employment status - current: Unemployed',
#  '82589-3': 'Highest level of education: High school diploma or GED',
#  '56799-0': 'Address',
#  '93033-9': 'Are you worried about losing your housing?: No',
#  '71802-3': 'Housing status: I have housing',
#  '63512-8': 'How many people are living or staying at this address?',
#  '54899-0': 'Preferred language: English',
#  '93034-7': 'Have you been discharged from the armed forces of the United States?: No',
#  '93035-4': "At any point in the past 2 years, has season or migrant farm work been your or your family's main source of income?: No",
#  '32624-9': 'Race: White',
#  '56051-6': 'Do you consider yourself Hispanic/Latino?: No',
#  '59460-6': 'Fall risk total [Morse Fall Scale]',
#  '59461-4': 'Fall risk level [Morse Fall Scale]: Moderate Risk (MFS Score 25 - 45)',
#  '55758-7': 'Patient Health Questionnaire 2 item (PHQ-2) total score [Reported]',
#  '710824005': 'Assessment of health and social care needs (procedure)',
#  '762993000': 'Assessment using Morse Fall Scale (procedure)',
#  '454711000124102': 'Depression screening using Patient Health Questionnaire Two-Item score (procedure)',
#  '308335008': 'Patient encounter procedure',
#  '1871000124103': 'Transition from acute care to home-health care (finding)',
#  '417511005': 'Referral to home health care service (procedure)',
#  '439708006': 'Home visit (procedure)',
#  '315639002': 'Initial patient assessment (procedure)',
#  '200619008': 'Comprehensive interview and evaluation (procedure)',
#  '370789001': 'Development of individualized plan of care (procedure)',
#  '711069006': 'Coordination of care plan (procedure)',
#  '410401003': 'Nursing care/supplementary surveillance (regime/therapy)',
#  '91251008': 'Physical therapy procedure (regime/therapy)',
#  '385781007': 'Home health aide service (regime/therapy)',
#  '311555007': 'Speech and language therapy regime (regime/therapy)',
#  '58000006': 'Patient discharge (procedure)',
#  '2093-3': 'Cholesterol [Mass/volume] in Serum or Plasma',
#  '2571-8': 'Triglycerides',
#  '18262-6': 'Low Density Lipoprotein Cholesterol',
#  '2085-9': 'Cholesterol in HDL [Mass/volume] in Serum or Plasma',
#  '275978004': 'Screening for malignant neoplasm of colon (procedure)',
#  '68496003': 'Polyp of colon',
#  '33756-8': 'Polyp size greatest dimension',
#  '57905-2': 'Hemoglobin.gastrointestinal.lower [Presence] in Stool by Immunoassay --1st specimen',
#  '73761001': 'Colonoscopy',
#  '104435004': 'Screening for occult blood in feces (procedure)',
#  '274031008': 'Rectal polypectomy',
#  '82667-7': 'Total score [DAST-10]',
#  '713106006': 'Screening for drug abuse (procedure)',
#  '713197008': 'Recurrent rectal polyp',
#  '75626-2': 'Total score [AUDIT-C]',
#  '763302001': 'Assessment using Alcohol Use Disorders Identification Test - Consumption (procedure)',
#  '702927004': 'Urgent care clinic (environment)',
#  '431855005': 'Chronic kidney disease stage 1 (disorder)',
#  '127013003': 'Disorder of kidney due to diabetes mellitus (disorder)',
#  '73438004': 'Unemployed (finding)',
#  '2345-7': 'Glucose [Mass/volume] in Serum or Plasma',
#  '3094-0': 'Urea nitrogen [Mass/volume] in Serum or Plasma',
#  '2160-0': 'Creatinine [Mass/volume] in Serum or Plasma',
#  '17861-6': 'Calcium [Mass/volume] in Serum or Plasma',
#  '2951-2': 'Sodium [Moles/volume] in Serum or Plasma',
#  '2823-3': 'Potassium [Moles/volume] in Serum or Plasma',
#  '2075-0': 'Chloride [Moles/volume] in Serum or Plasma',
#  '2028-9': 'Asian',
#  '33914-3': 'Glomerular filtration rate/1.73 sq M.predicted [Volume Rate/Area] in Serum or Plasma by Creatinine-based formula (MDRD)',
#  '5767-9': 'Appearance of Urine',
#  '7766007': 'Cloudy urine (finding)',
#  '34533-0': 'Odor of Urine',
#  '167248002': 'Urine smell ammoniacal (finding)',
#  '32167-9': 'Clarity of Urine',
#  '300828005': 'Translucent (qualifier value)',
#  '5778-6': 'Color of Urine',
#  '371254008': 'Brown color (qualifier value)',
#  '5792-7': 'Glucose [Mass/volume] in Urine by Test strip',
#  '25428-4': 'Glucose [Presence] in Urine by Test strip',
#  '167265006': 'Urine glucose test = ++ (finding)',
#  '20505-4': 'Bilirubin.total [Mass/volume] in Urine by Test strip',
#  '5770-3': 'Bilirubin.total [Presence] in Urine by Test strip',
#  '275778006': 'Finding of bilirubin in urine (finding)',
#  '5797-6': 'Ketones [Mass/volume] in Urine by Test strip',
#  '2514-8': 'Ketones [Presence] in Urine by Test strip',
#  '167288007': 'Urine ketone test = trace (finding)',
#  '5811-5': 'Specific gravity of Urine by Test strip',
#  '5803-2': 'pH of Urine by Test strip',
#  '5804-0': 'Protein [Mass/volume] in Urine by Test strip',
#  '20454-5': 'Protein [Presence] in Urine by Test strip',
#  '167275009': 'Urine protein test = + (finding)',
#  '5802-4': 'Nitrite [Presence] in Urine by Test strip',
#  '314138001': 'Urine nitrite negative (finding)',
#  '5794-3': 'Hemoglobin [Presence] in Urine by Test strip',
#  '167297006': 'Urine blood test = negative (finding)',
#  '5799-2': 'Leukocyte esterase [Presence] in Urine by Test strip',
#  '394717006': 'Urine leukocyte test negative (finding)',
#  '76504-0': 'Total score [HARK]',
#  '866148006': 'Screening for domestic abuse (procedure)',
#  '10509002': 'Acute bronchitis (disorder)',
#  '23426006': 'Measurement of respiratory function (procedure)',
#  '44261-6': 'Patient Health Questionnaire 9 item (PHQ-9) total score [Reported]',
#  '50849002': 'Emergency room admission (procedure)',
#  '312608009': 'Laceration - injury (disorder)',
#  '370247008': 'Facial laceration',
#  '288086009': 'Suture open wound',
#  '431856006': 'Chronic kidney disease stage 2 (disorder)',
#  '90781000119102': 'Microalbuminuria due to type 2 diabetes mellitus (disorder)',
#  '167289004': 'Urine ketone test = + (finding)',
#  '167276005': 'Urine protein test = ++ (finding)',
#  '424393004': 'Reports of violence in the environment (finding)',
#  '741062008': 'Not in labor force (finding)',
#  '433144002': 'Chronic kidney disease stage 3 (disorder)',
#  '157141000119108': 'Proteinuria due to type 2 diabetes mellitus (disorder)',
#  '167290008': 'Urine ketone test = ++ (finding)',
#  '424441002': 'Prenatal initial visit',
#  '72892002': 'Normal pregnancy',
#  '424619006': 'Prenatal visit',
#  '271442007': 'Fetal anatomy study',
#  '275833003': 'AFP test - antenatal',
#  '274804006': 'Evaluation of uterine fundal height',
#  '225158009': 'Auscultation of the fetal heart',
#  '104091002': 'Hemogram, automated, with RBC, WBC, Hgb, Hct, Indices, Platelet count, and manual WBC differential',
#  '399014008': 'Administration of diphtheria, pertussis, and tetanus vaccine',
#  '268556000': 'Urine screening for glucose',
#  '118001005': 'Streptococcus pneumoniae group B antigen assay',
#  '183460006': 'Obstetric emergency hospital admission',
#  '236974004': 'Instrumental delivery',
#  '66348005': 'Childbirth',
#  '169762003': 'Postnatal visit',
#  '5880005': 'Physical examination procedure (procedure)',
#  '76601001': 'Intramuscular injection',
#  '1000126': '1 ML medroxyprogesterone acetate 150 MG/ML Injection',
#  '807283': 'Mirena 52 MG Intrauterine System',
#  '65200003': 'Insertion of intrauterine contraceptive device',
#  '252160004': 'Standard pregnancy test',
#  '169230002': 'Ultrasound scan for fetal viability',
#  '44608003': 'Blood group typing (procedure)',
#  '47758006': 'Hepatitis B Surface Antigen Measurement',
#  '31676001': 'Human immunodeficiency virus antigen test',
#  '310861008': 'Chlamydia antigen test',
#  '165829005': 'Gonorrhea infection titer test (procedure)',
#  '269828009': 'Syphilis infectious titer test (procedure)',
#  '117010004': 'Urine culture',
#  '90226004': 'Cytopathology procedure, preparation of smear, genital source',
#  '395123002': 'Urine screening test for diabetes',
#  '104375008': 'Hepatitis C antibody, confirmatory test',
#  '169690007': 'Rubella screening',
#  '104326007': 'Measurement of Varicella-zoster virus antibody',
#  '28163009': 'Skin test for tuberculosis, Tine test (procedure)',
#  '167271000': 'Urine protein test',
#  '443529005': 'Detection of chromosomal aneuploidy in prenatal amniotic fluid specimen using fluorescence in situ hybridization screening technique (procedure)',
#  '237001001': 'Augmentation of labor',
#  '110030002': 'Concussion injury of brain (disorder)',
#  '62106007': 'Concussion with no loss of consciousness',
#  '2135-2': 'Hispanic or Latino',
#  '5251000175109': 'Received certificate of high school equivalency (finding)',
#  '156073000': 'Complete miscarriage (disorder)',
#  '161744009': 'Past pregnancy history of miscarriage (situation)',
#  '8517006': 'Ex-smoker (finding)',
#  '19169002': 'Miscarriage in first trimester',
#  '31208007': 'Medical induction of labor',
#  '169553002': 'Insertion of subcutaneous contraceptive',
#  '389221': 'Etonogestrel 68 MG Drug Implant',
#  '162573006': 'Suspected lung cancer (situation)',
#  '399208008': 'Plain chest X-ray (procedure)',
#  '418891003': 'Computed tomography of chest and abdomen',
#  '254637007': 'Non-small cell lung cancer (disorder)',
#  '173160006': 'Diagnostic fiberoptic bronchoscopy (procedure)',
#  '20570-8': 'Hematocrit [Volume Fraction] of Blood',
#  '14768001': 'Peripheral blood smear interpretation',
#  '415300000': 'Review of systems (procedure)',
#  '162676008': 'Brief general examination (procedure)',
#  '424132000': 'Non-small cell carcinoma of lung, TNM stage 1 (disorder)',
#  '698354004': 'Magnetic resonance imaging for measurement of brain volume (procedure)',
#  '2885-2': 'Protein [Mass/volume] in Serum or Plasma',
#  '1751-7': 'Albumin [Mass/volume] in Serum or Plasma',
#  '10834-0': 'Globulin [Mass/volume] in Serum by calculation',
#  '1975-2': 'Bilirubin.total [Mass/volume] in Serum or Plasma',
#  '6768-6': 'Alkaline phosphatase [Enzymatic activity/volume] in Serum or Plasma',
#  '1742-6': 'Alanine aminotransferase [Enzymatic activity/volume] in Serum or Plasma',
#  '1920-8': 'Aspartate aminotransferase [Enzymatic activity/volume] in Serum or Plasma',
#  '167291007': 'Urine ketone test = +++ (finding)',
#  '167277001': 'Urine protein test = +++ (finding)',
#  '398171003': 'Hearing examination (procedure)',
#  '703423002': 'Combined chemotherapy and radiation therapy (procedure)',
#  '1736854': 'Cisplatin 50 MG Injection',
#  '583214': 'Paclitaxel 100 MG Injection',
#  '16335031000119103': 'High resolution computed tomography of chest without contrast (procedure)',
#  '82423001': 'Chronic pain (finding)',
#  '278860009': 'Chronic low back pain (finding)',
#  '91148-7': 'Pain intensity, Enjoyment of life, General activity (PEG) 3 item pain scale',
#  '91146-1': 'What number best describes how pain has interfered with your general activity during the past week',
#  '91145-3': 'What number best describes how pain has interfered with your enjoyment of life during the past week',
#  '75893-8': 'Pain severity in the past week - 0-10 numeric rating [Reported]',
#  '65750-2': 'Drugs of abuse 5 panel - Urine by Screen method',
#  '260385009': 'Negative (qualifier value)',
#  '390906007': 'Follow-up encounter (procedure)',
#  '301807007': 'Removal of subcutaneous contraceptive',
#  '305336008': 'Admission to hospice (procedure)',
#  '310417005': 'Certification procedure (procedure)',
#  '185087000': 'Notifications (procedure)',
#  '385763009': 'Hospice care (regime/therapy)',
#  '308646001': 'Death Certification',
#  '69453-9': 'Cause of Death [US Standard Certificate of Death]',
#  '105531004': 'Housing unsatisfactory (finding)',
#  '224295006': 'Only received primary school education (finding)',
#  '74400008': 'Appendicitis',
#  '01': 'Discharged to home care or self care (routine discharge)',
#  '428251008': 'History of appendectomy',
#  '307426000': 'Acute infective cystitis (disorder)',
#  '75636-1': 'Emergency severity index: Needs 1 resource',
#  '2708-6': 'Oxygen saturation in Arterial blood',
#  '59408-5': 'Oxygen saturation in Arterial blood by Pulse oximetry',
#  '167287002': 'Urine ketone test negative (finding)',
#  '314137006': 'Urine nitrite positive (finding)',
#  '167300001': 'Urine blood test = + (finding)',
#  '394712000': 'Urine leukocyte test = + (finding)',
#  '5821-4': 'WBCs',
#  '13945-1': 'RBCs',
#  '5787-7': 'Epithelial Cells',
#  '24124-0': 'Casts',
#  '167336003': 'Urine microscopy: no casts (finding)',
#  '8247-9': 'Mucus Threads',
#  '276409005': 'Mucus in urine (finding)',
#  '5769-5': 'Bacteria',
#  '365691004': 'Finding of presence of bacteria (finding)',
#  '630-4': 'Bacteria identified in Urine by Culture',
#  '84100007': 'History taking (procedure)',
#  '223470000': 'Discussion about signs and symptoms (procedure)',
#  '386478007': 'Triage emergency center (procedure)',
#  '61746007': 'Taking patient vital signs (procedure)',
#  '14736009': 'History and physical examination with evaluation and management of patient (procedure)',
#  '441550005': 'Urinalysis with reflex to microscopy and culture (procedure)',
#  '57617002': 'Urine specimen collection (procedure)',
#  '281789004': 'Antibiotic therapy (procedure)',
#  '449411000124106': 'Admission to skilled nursing facility (procedure)',
#  '25675004': 'Patient transfer to skilled nursing facility (procedure)',
#  '63332003': 'History AND physical examination (procedure)',
#  '84478008': 'Occupational therapy (regime/therapy)',
#  '409023009': 'Professional / ancillary services care (regime/therapy)',
#  '392091000': 'Care regimes assessment (procedure)',
#  '225386006': 'Pre-discharge assessment (procedure)',
#  '449381000124108': 'Discharge from skilled nursing facility (procedure)',
#  '182813001': 'Emergency treatment (procedure)',
#  '196416002': 'Impacted molars',
#  '124171000119105': 'Chronic intractable migraine without aura',
#  '183452005': 'Emergency hospital admission (procedure)',
#  '6525002': 'Dependent drug abuse (disorder)',
#  '55680006': 'Drug overdose',
#  '446654005': 'Refugee (person)',
#  '52052004': 'Rehabilitation therapy (regime/therapy)',
#  '56876005': 'Drug rehabilitation and detoxification',
#  '80583007': 'Severe anxiety (panic) (finding)',
#  '75498004': 'Acute bacterial sinusitis (disorder)',
#  '40055000': 'Chronic sinusitis (disorder)',
#  '55822004': 'Hyperlipidemia',
#  '125605004': 'Fracture of bone (disorder)',
#  '58150001': 'Fracture of clavicle',
#  '38265-5': 'DXA Radius and Ulna [T-score] Bone density',
#  '168594001': 'Clavicle X-ray',
#  '305428000': 'Admission to orthopedic department',
#  '312681000': 'Bone density scan (procedure)',
#  '233678006': 'Childhood asthma',
#  '36971009': 'Sinusitis (disorder)',
#  '394701000': 'Asthma follow-up',
#  '195967001': 'Asthma',
#  '361055000': 'Misuses drugs (finding)',
#  '3718001': "Cow's milk (substance)",
#  '419199007': 'Allergy to substance (finding)',
#  '446096008': 'Perennial allergic rhinitis',
#  '48333001': 'Burn injury (morphologic abnormality)',
#  '403190006': 'Epidermal burn of skin (disorder)',
#  '65363002': 'Otitis media',
#  '170837001': 'Allergic disorder initial assessment',
#  '305408004': 'Admission to surgical department',
#  '183996000': 'Sterilization requested (situation)',
#  '267020005': 'History of tubal ligation (situation)',
#  '76164006': 'Biopsy of colon',
#  '93761005': 'Primary malignant neoplasm of colon',
#  '412071004': 'Wheat (substance)',
#  '371883000': 'Outpatient procedure',
#  '197927001': 'Recurrent urinary tract infection (disorder)',
#  '270427003': 'Patient-initiated encounter',
#  '10383002': 'Counseling for termination of pregnancy',
#  '714812005': 'Induced termination of pregnancy',
#  '386394001': 'Pregnancy termination care',
#  '35999006': 'Blighted ovum',
#  '90460009': 'Injury of neck (disorder)',
#  '39848009': 'Whiplash injury to neck',
#  '1121000119107': 'Chronic neck pain (finding)',
#  '266934004': 'Transport problem (finding)',
#  '713458007': 'Lack of access to transportation (finding)',
#  '762952008': 'Peanut (substance)',
#  '44054006': 'Diabetes mellitus type 2 (disorder)',
#  '14959-1': 'Microalbumin/Creatinine [Mass Ratio] in Urine',
#  '384709000': 'Sprain (morphologic abnormality)',
#  '44465007': 'Sprain of ankle',
#  '198992004': 'Antepartum eclampsia',
#  '51116004': 'Passive immunization (procedure)',
#  '10939881000119105': 'Unhealthy alcohol drinking behavior (finding)',
#  '169673001': 'Antenatal RhD antibody screening',
#  '11466000': 'Cesarean section',
#  '283385000': 'Laceration of thigh',
#  '201834006': 'Localized, primary osteoarthritis of the hand',
#  '22298006': 'Myocardial infarction (disorder)',
#  '401314000': 'Acute non-ST segment elevation myocardial infarction (disorder)',
#  '788-0': 'Erythrocyte distribution width [Ratio] by Automated count',
#  '21377-7': 'Magnesium [Mass/volume] in Blood',
#  '6301-6': 'INR in Platelet poor plasma by Coagulation assay',
#  '3173-2': 'aPTT in Blood by Coagulation assay',
#  '71425-3': 'Natriuretic peptide.B prohormone N-Terminal [Mass/volume] in Blood by Immunoassay',
#  '89579-7': 'Troponin I.cardiac [Mass/volume] in Serum or Plasma by High sensitivity method',
#  '710839006': 'Assessment of cardiac status using monitoring device (procedure)',
#  '29303009': 'Electrocardiographic procedure (procedure)',
#  '371908008': 'Oxygen administration by mask (procedure)',
#  '15220000': 'Laboratory test (procedure)',
#  '165197003': 'Diagnostic assessment (procedure)',
#  '212033': 'aspirin 325 MG Oral Tablet',
#  '32485007': 'Hospital admission (procedure)',
#  '399211009': 'History of myocardial infarction (situation)',
#  '18752-6': 'Exercise stress test study',
#  '439590007': 'Cardiovascular stress test abnormal (finding)',
#  '225338004': 'Risk assessment (procedure)',
#  '76746007': 'Cardiovascular stress testing (procedure)',
#  '33367005': 'Angiography of coronary artery (procedure)',
#  '415070008': 'Percutaneous coronary intervention (procedure)',
#  '433236007': 'Transthoracic echocardiography (procedure)',
#  '1997015': 'bivalirudin 50 ML; 5 MG/ML Injection',
#  '749196': 'clopidogrel 300 MG Oral Tablet',
#  '64859006': 'Osteoporosis (disorder)',
#  '735029006': 'Shellfish (substance)',
#  'X9999-0': 'Operative Status',
#  'X9999-2': 'Priority Level',
#  'X9999-1': 'Operative Status Value',
#  '183519002': 'Referral to cardiology service (procedure)',
#  '736169004': 'Post anesthesia care management (procedure)',
#  '403191005': 'Second degree burn',
#  '302870006': 'Hypertriglyceridemia (disorder)',
#  '77606-2': 'Weight-for-length Per age and sex',
#  '8289-1': 'Head Occipital-frontal circumference Percentile',
#  '9843-4': 'Head Occipital-frontal circumference',
#  '1856546': 'Kyleena 19.5 MG Intrauterine System',
#  '68254000': 'Removal of intrauterine device',
#  '79586000': 'Tubal pregnancy',
#  '236931002': 'Methotrexate injection into tubal pregnancy',
#  '133899007': 'Postoperative care (regime/therapy)',
#  '38208-5': 'Pain severity - Reported',
#  '229064008': 'Movement therapy (regime/therapy)',
#  '67879005': 'History and physical examination, limited (procedure)',
#  '386053000': 'Evaluation procedure (procedure)',
#  '18946005': 'Epidural anesthesia',
#  '40275004': 'Contact dermatitis',
#  '267253006': 'Fetus with chromosomal abnormality',
#  '239873007': 'Osteoarthritis of knee',
#  '46706006': 'Replacement of contraceptive intrauterine device',
#  '85548006': 'Episiotomy',
#  '1605257': 'Liletta 52 MG Intrauterine System',
#  '609496007': 'Complication occuring during pregnancy',
#  '224355006': 'Served in armed forces (finding)',
#  '87433001': 'Pulmonary emphysema (disorder)',
#  '19926-5': 'FEV1/FVC',
#  '127783003': 'Spirometry (procedure)',
#  '22523008': 'Vasectomy',
#  '359817006': 'Closed fracture of hip',
#  '268425006': 'Pelvis X-ray',
#  '70704007': 'Sprain of wrist',
#  '840544004': 'Suspected COVID-19',
#  '248595008': 'Sputum finding (finding)',
#  '386661006': 'Fever (finding)',
#  '840539006': 'COVID-19',
#  '92142-9': 'Influenza virus A RNA [Presence] in Respiratory specimen by NAA with probe detection',
#  '92141-1': 'Influenza virus B RNA [Presence] in Respiratory specimen by NAA with probe detection',
#  '92131-2': 'Respiratory syncytial virus RNA [Presence] in Respiratory specimen by NAA with probe detection',
#  '92140-3': 'Parainfluenza virus 1 RNA [Presence] in Respiratory specimen by NAA with probe detection',
#  '92139-5': 'Parainfluenza virus 2 RNA [Presence] in Respiratory specimen by NAA with probe detection',
#  '92138-7': 'Parainfluenza virus 3 RNA [Presence] in Respiratory specimen by NAA with probe detection',
#  '92130-4': 'Rhinovirus RNA [Presence] in Respiratory specimen by NAA with probe detection',
#  '92134-6': 'Human metapneumovirus RNA [Presence] in Respiratory specimen by NAA with probe detection',
#  '94040-3': 'Adenovirus A+B+C+D+E DNA [Presence] in Respiratory specimen by NAA with probe detection',
#  '94531-1': 'SARS-CoV-2 RNA Pnl Resp NAA+probe',
#  '260373001': 'Detected (qualifier value)',
#  '261352009': 'Face mask (physical object)',
#  '90560007': 'Gout',
#  '60234000': 'Aortic valve regurgitation (disorder)',
#  '1231000119100': 'History of aortic valve replacement (situation)',
#  '305342007': 'Admission to ward (procedure)',
#  '440546007': 'Discussion about pregnancy (procedure)',
#  '65966004': 'Fracture of forearm',
#  '1225002': 'Upper arm X-ray',
#  '274474001': 'Bone immobilization',
#  '735971005': 'Fish (substance)',
#  '263102004': 'Fracture subluxation of wrist',
#  '60027007': 'Radiography of wrist (procedure)',
#  '453131000124105': 'Videotelephony encounter (procedure)',
#  '448337001': 'Telemedicine consultation with patient (procedure)',
#  '266753000': 'Referral for laboratory tests (procedure)',
#  '185316007': 'Indirect encounter (procedure)',
#  '165355002': 'Patient informed - test result (situation)',
#  '410299006': 'Lab findings education, guidance, and counseling (procedure)',
#  '223484005': 'Discussion about treatment (procedure)',
#  '33633005': 'Prescription of drug (procedure)',
#  '284549007': 'Laceration of hand',
#  '192127007': 'Child attention deficit disorder',
#  '65546002': 'Extraction of wisdom tooth',
#  '91302008': 'Sepsis (disorder)',
#  '1': 'Discharge to home',
#  '401303003': 'Acute ST segment elevation myocardial infarction (disorder)',
#  '198039': 'nitroglycerin 0.4 MG Sublingual Tablet',
#  '1728805': '2 ML morphine sulfate 1 MG/ML Injection',
#  '1361048': 'heparin sodium, porcine 100 UNT/ML Injectable Solution',
#  '1116635': 'ticagrelor 90 MG Oral Tablet',
#  '283545005': 'Gunshot wound (disorder)',
#  '262574004': 'Bullet wound',
#  '232353008': 'Perennial allergic rhinitis with seasonal variation',
#  '33737001': 'Fracture of rib',
#  '442571000124108': 'Tree nut (substance)',
#  '241929008': 'Acute allergic reaction',
#  '313191000': 'Injection of epinephrine (procedure)',
#  '312617': 'predniSONE 5 MG Oral Tablet',
#  '6206-7': 'Peanut IgE Ab [Units/volume] in Serum',
#  '6273-7': 'Walnut IgE Ab [Units/volume] in Serum',
#  '6082-2': 'Codfish IgE Ab [Units/volume] in Serum',
#  '6246-3': 'Shrimp IgE Ab [Units/volume] in Serum',
#  '6276-0': 'Wheat IgE Ab [Units/volume] in Serum',
#  '6106-9': 'Egg white IgE Ab [Units/volume] in Serum',
#  '6248-9': 'Soybean IgE Ab [Units/volume] in Serum',
#  '7258-7': 'Cow milk IgE Ab [Units/volume] in Serum',
#  '6189-5': 'White oak IgE Ab [Units/volume] in Serum',
#  '6085-5': 'Common Ragweed IgE Ab [Units/volume] in Serum',
#  '6833-8': 'Cat dander IgE Ab [Units/volume] in Serum',
#  '6095-4': 'American house dust mite IgE Ab [Units/volume] in Serum',
#  '6075-6': 'Cladosporium herbarum IgE Ab [Units/volume] in Serum',
#  '6844-5': 'Honey bee IgE Ab [Units/volume] in Serum',
#  '6158-0': 'Latex IgE Ab [Units/volume] in Serum',
#  '395142003': 'Allergy screening test',
#  '180256009': 'Subcutaneous immunotherapy',
#  '269911007': 'Sputum examination (procedure)',
#  '128613002': 'Seizure disorder',
#  '703151001': 'History of single seizure (situation)',
#  '54550000': 'Electroencephalogram (procedure)',
#  '84757009': 'Epilepsy',
#  '95281009': 'Sudden Cardiac Death',
#  '171231001': 'Asthma screening',
#  '68235000': 'Nasal congestion (finding)',
#  '49727002': 'Cough (finding)',
#  '36955009': 'Loss of taste (finding)',
#  '183478001': 'Emergency hospital admission for asthma',
#  '399261000': 'History of coronary artery bypass grafting (situation)',
#  '449868002': 'Smokes tobacco daily (finding)',
#  '284551006': 'Laceration of foot',
#  '39898005': 'Sleep disorder (disorder)',
#  '78275009': 'Obstructive sleep apnea syndrome (disorder)',
#  '103750000': 'Sleep apnea assessment (procedure)',
#  '306185001': 'Referral to cardiac surgery service (procedure)',
#  '19123-9': 'Magnesium [Mass/volume] in Serum or Plasma',
#  '2777-1': 'Phosphate [Mass/volume] in Serum or Plasma',
#  '5902-2': 'Prothrombin time (PT)',
#  '2744-1': 'pH of Arterial blood',
#  '2019-8': 'Carbon dioxide [Partial pressure] in Arterial blood',
#  '2703-7': 'Oxygen [Partial pressure] in Arterial blood',
#  '1960-4': 'Bicarbonate [Moles/volume] in Arterial blood',
#  '3184-9': 'Activated clotting time (ACT) of Blood by Coagulation assay',
#  '2746-6': 'pH of Venous blood',
#  '2021-4': 'Carbon dioxide [Partial pressure] in Venous blood',
#  '2705-2': 'Oxygen [Partial pressure] in Venous blood',
#  '14627-4': 'Bicarbonate [Moles/volume] in Venous blood',
#  '2027-1': 'Carbon dioxide, total [Moles/volume] in Venous blood',
#  '29554-3': 'Procedure Narrative',
#  '110467000': 'Pre-surgery testing (procedure)',
#  '709138001': 'Notification of treatment plan (procedure)',
#  '410538000': 'Scheduling (procedure)',
#  '116861002': 'Transfusion of fresh frozen plasma (procedure)',
#  '392247006': 'Insertion of catheter into artery (procedure)',
#  '410770002': 'Administration of anesthesia for procedure (procedure)',
#  '52765003': 'Intubation',
#  '65677008': 'Pulmonary catheterization with Swan-Ganz catheter (procedure)',
#  '223495004': 'Preparation of patient for procedure (regime/therapy)',
#  '359672006': 'Median sternotomy (procedure)',
#  '414088005': 'Emergency coronary artery bypass graft (procedure)',
#  '23745001': 'Documentation procedure (procedure)',
#  '1665060': 'cefazolin 2000 MG Injection',
#  '1659263': '1 ML heparin sodium, porcine 5000 UNT/ML Injection',
#  '1796676': '25 ML protamine sulfate (USP) 10 MG/ML Injection',
#  '1740467': '2 ML Ondansetron 2 MG/ML Injection',
#  '311700': 'Midazolam 1 MG/ML Injectable Solution',
#  '1808217': '100 ML Propofol 10 MG/ML Injection',
#  '1234995': 'Rocuronium bromide 10 MG/ML Injectable Solution',
#  '542347': 'isoflurane 99.9 % Inhalation Solution',
#  '1729584': 'remifentanil 2 MG Injection',
#  '80394007': 'Hyperglycemia (disorder)',
#  '368581000119106': 'Neuropathy due to type 2 diabetes mellitus (disorder)',
#  '431857002': 'Chronic kidney disease stage 4 (disorder)',
#  '74006-8': 'Weight difference [Mass difference] --pre dialysis - post dialysis',
#  '265764009': 'Renal dialysis (procedure)',
#  '205923': '1 ML Epoetin Alfa 4000 UNT/ML Injection [Epogen]',
#  '698306007': 'Awaiting transplantation of kidney (situation)',
#  '306316000': 'Referral to transplant surgeon (procedure)',
#  '88805009': 'Chronic congestive heart failure (disorder)',
#  '75325-1': 'Symptom',
#  '60845006': 'Dyspnea on exertion (finding)',
#  '267036007': 'Dyspnea (finding)',
#  '59265000': 'Paroxysmal dyspnea (finding)',
#  '62744007': 'Orthopnea (finding)',
#  '267038008': 'Edema (finding)',
#  '19283009': 'Rales (finding)',
#  '33762-6': 'NT-proBNP',
#  '2276-4': 'Ferritin [Mass/volume] in Serum or Plasma',
#  '2498-4': 'Iron [Mass/volume] in Serum or Plasma',
#  '2500-7': 'Iron binding capacity [Mass/volume] in Serum or Plasma',
#  '2502-3': 'Iron saturation [Mass Fraction] in Serum or Plasma',
#  '88020-3': 'Functional capacity NYHA: Class II',
#  '88021-1': 'Objective assessment of cardiovascular disease NYHA: Objective evidence of severe cardiovascular disease',
#  '762998009': 'Assessment using New York Heart Association Classification (procedure)',
#  '10230-1': 'Left ventricular Ejection fraction',
#  '40701008': 'Echocardiography (procedure)',
#  '431182000': 'Placing subject in prone position (procedure)',
#  '305351004': 'Admission to intensive care unit (procedure)',
#  '1719286': '10 ML Furosemide 10 MG/ML Injection',
#  '37849005': 'Congenital uterine anomaly',
#  '230690007': 'Stroke',
#  '203082005': 'Fibromyalgia (disorder)',
#  '3016-3': 'Thyrotropin [Units/volume] in Serum or Plasma',
#  '709979004': 'Doppler ultrasonography of artery (procedure)',
#  '303653007': 'Computed tomography of head (procedure)',
#  '42825003': 'Cannulation (procedure)',
#  '63697000': 'Cardiopulmonary bypass operation (procedure)',
#  '301882004': 'Placement of aortic cross clamp (procedure)',
#  '8290005': 'Induced cardioplegia (procedure)',
#  '232717009': 'Coronary artery bypass grafting (procedure)',
#  '301884003': 'Removal of aortic cross clamp (procedure)',
#  '233553003': 'Vascular cannula removal (procedure)',
#  '397821002': 'Patient transfer to intensive care unit (procedure)',
#  '271280005': 'Removal of endotracheal tube (procedure)',
#  '71493000': 'Transfusion of packed red blood cells (procedure)',
#  '306706006': 'Discharge to ward (procedure)',
#  '243063003': 'Postoperative procedure education (procedure)',
#  '302761001': 'Walking exercise test (procedure)',
#  '252482003': 'Stair-climbing test (procedure)',
#  '308283009': 'Discharge from hospital (procedure)',
#  '7200002': 'Alcoholism',
#  '46177005': 'End-stage renal disease (disorder)',
#  '16114001': 'Fracture of ankle',
#  '19490002': 'Ankle X-ray',
#  '125601008': 'Injury of knee (disorder)',
#  '444470001': 'Injury of anterior cruciate ligament',
#  '74016001': 'Knee X-ray',
#  '183495009': 'Non-urgent orthopedic admission',
#  '699253003': 'Surgical manipulation of joint of knee',
#  '307731004': 'Injury of tendon of the rotator cuff of shoulder',
#  '25064002': 'Headache (finding)',
#  '84229001': 'Fatigue (finding)',
#  '1505002': 'Hospital admission for isolation (procedure)',
#  '233604007': 'Pneumonia (disorder)',
#  '389087006': 'Hypoxemia (disorder)',
#  '271825005': 'Respiratory distress (finding)',
#  '770349000': 'Sepsis caused by virus (disorder)',
#  '132281000119108': 'Acute deep venous thrombosis (disorder)',
#  '770-8': 'Neutrophils/100 leukocytes in Blood by Automated count',
#  '736-9': 'Lymphocytes/100 leukocytes in Blood by Automated count',
#  '5905-5': 'Monocytes/100 leukocytes in Blood by Automated count',
#  '713-8': 'Eosinophils/100 leukocytes in Blood by Automated count',
#  '706-2': 'Basophils/100 leukocytes in Blood by Automated count',
#  '751-8': 'Neutrophils [#/volume] in Blood by Automated count',
#  '731-0': 'Lymphocytes [#/volume] in Blood by Automated count',
#  '742-7': 'Monocytes [#/volume] in Blood by Automated count',
#  '711-2': 'Eosinophils [#/volume] in Blood by Automated count',
#  '704-7': 'Basophils [#/volume] in Blood by Automated count',
#  '48065-7': 'Fibrin D-dimer FEU [Mass/volume] in Platelet poor plasma',
#  '14804-9': 'Lactate dehydrogenase [Enzymatic activity/volume] in Serum or Plasma by Lactate to pyruvate reaction',
#  '2532-0': 'Lactate dehydrogenase [Enzymatic activity/volume] in Serum or Plasma',
#  '2157-6': 'Creatine kinase [Enzymatic activity/volume] in Serum or Plasma',
#  '1988-5': 'C reactive protein [Mass/volume] in Serum or Plasma',
#  '33959-8': 'Procalcitonin [Mass/volume] in Serum or Plasma',
#  '260415000': 'Not detected (qualifier value)',
#  '854235': '0.4 ML Enoxaparin sodium 100 MG/ML Prefilled Syringe',
#  '198440': 'Acetaminophen 500 MG Oral Tablet',
#  '854252': '1 ML Enoxaparin sodium 150 MG/ML Prefilled Syringe',
#  '183444007': 'Referral for further care (procedure)',
#  '185086009': 'Chronic obstructive bronchitis (disorder)',
#  '15081005': 'Pulmonary rehabilitation (regime/therapy)',
#  '26604007': 'Complete blood count (procedure)',
#  '866146005': 'Serum metabolic panel (procedure)',
#  '56018004': 'Wheezing (finding)',
#  '80382-5': 'Influenza virus A Ag [Presence] in Upper respiratory specimen by Rapid immunoassay',
#  '80383-3': 'Influenza virus B Ag [Presence] in Upper respiratory specimen by Rapid immunoassay',
#  '706870000': 'Acute pulmonary embolism (disorder)',
#  '2123111': 'NDA020503 200 ACTUAT Albuterol 0.09 MG/ACTUAT Metered Dose Inhaler',
#  '855812': 'prasugrel 10 MG Oral Tablet',
#  '418824004': 'Off-pump coronary artery bypass (procedure)',
#  '32911000': 'Homeless (finding)',
#  '210098006': 'Domiciliary or rest home patient evaluation and management',
#  '76690-7': 'Sexual orientation',
#  '55277-8': 'HIV status',
#  '28245-9': 'Abuse Status [OMAHA]',
#  '63513-6': 'Are you covered by health insurance or some other kind of health care plan [PhenX]',
#  '46240-8': 'History of Hospitalizations+Outpatient visits Narrative',
#  '311791003': 'Information gathering (procedure)',
#  '228557008': 'Cognitive and behavioral therapy (regime/therapy)',
#  '290045001': 'Kitchen practice',
#  '229095001': 'Exercise class',
#  '398254007': 'Preeclampsia',
#  '268533009': 'Sterilization education (procedure)',
#  '287664005': 'Bilateral tubal ligation',
#  '27942005': 'Shock (disorder)',
#  '423475008': 'Heart failure education (procedure)',
#  '86013001': 'Periodic reevaluation and management of healthy individual (procedure)',
#  '268547008': 'Screening for malignant neoplasm of breast (procedure)',
#  '254837009': 'Malignant neoplasm of breast (disorder)',
#  '439740005': 'Postoperative follow-up visit (procedure)',
#  '25656009': 'Physical examination, complete (procedure)',
#  '410410006': 'Screening surveillance (regime/therapy)',
#  '71651007': 'Mammography (procedure)',
#  '310061009': 'Gynecology service (qualifier value)',
#  '35025007': 'Manual pelvic examination (procedure)',
#  '408512008': 'Body mass index 40+ - severely obese (finding)',
#  '44667-4': 'Site of distant metastasis in Breast tumor',
#  '260413007': 'None (qualifier value)',
#  '21907-1': 'Distant metastases.clinical [Class] Cancer',
#  '30893008': 'M0 category (finding)',
#  '33728-7': 'Size.maximum dimension in Tumor',
#  '21905-5': 'Primary tumor.clinical [Class] Cancer',
#  '23351008': 'T1 category (finding)',
#  '85352-3': 'Lymph nodes with isolated tumor cells [#] in Cancer specimen by Light microscopy',
#  '21906-3': 'Regional lymph nodes.clinical [Class] Cancer',
#  '62455006': 'N0 category (finding)',
#  '85319-2': 'HER2 [Presence] in Breast cancer specimen by Immune stain',
#  '85318-4': 'HER2 [Presence] in Breast cancer specimen by FISH',
#  '85337-4': 'Estrogen receptor Ag [Presence] in Breast cancer specimen by Immune stain',
#  '85339-0': 'Progesterone receptor Ag [Presence] in Breast cancer specimen by Immune stain',
#  '10480-2': 'Estrogen+Progesterone receptor Ag [Presence] in Tissue by Immune stain',
#  '21924-6': 'Tumor marker Cancer',
#  '21908-9': 'Stage group.clinical Cancer',
#  '261634002': 'Stage 1A (qualifier value)',
#  '258215001': 'Stage 1 (qualifier value)',
#  '241055006': 'Mammogram - symptomatic (procedure)',
#  '1571000087109': 'Ultrasonography of bilateral breasts (procedure)',
#  '122548005': 'Biopsy of breast (procedure)',
#  '434363004': 'Human epidermal growth factor receptor 2 gene detection by fluorescence in situ hybridization (procedure)',
#  '433114000': 'Human epidermal growth factor receptor 2 gene detection by immunohistochemistry (procedure)',
#  '223487003': 'Discussion about options (procedure)',
#  '367336001': 'Chemotherapy (procedure)',
#  '88040-1': 'Response to cancer treatment',
#  '385633008': 'Improving (qualifier value)',
#  '392021009': 'Lumpectomy of breast (procedure)',
#  '1734919': 'Cyclophosphamide 1000 MG Injection',
#  '33195004': 'External beam radiation therapy procedure (procedure)',
#  '59557-9': 'Treatment status Cancer',
#  '445528004': 'Treatment changed (situation)',
#  '309845': 'Diazepam 5 MG/ML Injectable Solution',
#  '562366': 'desflurane 1000 MG/ML Inhalation Solution',
#  '1809104': '5 ML SUFentanil 0.05 MG/ML Injection',
#  '12719002': 'Platelet transfusion (procedure)',
#  '170838006': 'Allergic disorder follow-up assessment',
#  '363406005': 'Malignant tumor of colon',
#  '43075005': 'Partial resection of colon',
#  '1803932': 'Leucovorin 100 MG Injection',
#  '1736776': '10 ML oxaliplatin 5 MG/ML Injection',
#  '427419006': 'Transformed migraine (disorder)',
#  '10828004': 'Positive (qualifier value)',
#  '5602001': 'Opioid abuse (disorder)',
#  '99999-0': 'DSM-5 Clinical Diagnostic Criteria for Opioid Use Disorder',
#  '99999-11': 'Withdrawal,* as manifested by either of the following: a) Characteristic opioid withdrawal syndrome b) Same (or a closely related) substance is taken to relieve or avoid withdrawal symptoms',
#  '99999-10': 'Tolerance,as defined by either of the following: a) Need for markedly increased amounts of opioids to achieve intoxication or desired effect b) Markedly diminished effect with continued use of the same amount of opioid',
#  '99999-9': 'Continued use despite knowledge of having a persistent or recurrent physical or psychological problem that is likely to have been caused or exacerbated by opioids.',
#  '99999-8': 'Recurrent opioid use in situations in which it is physically hazardous',
#  '99999-7': 'Important social, occupational, or recreational activities are given up or reduced because of opioid use',
#  '99999-6': 'Continued opioid use despite having persistent or recurrent social or interpersonal problems caused or exacerbated by the effects of opioids',
#  '99999-5': 'Recurrent opioid use resulting in a failure to fulfill major role obligations at work, school, or home',
#  '99999-4': 'Craving or a strong desire to use opioids',
#  '99999-3': 'A great deal of time is spent in activities necessary to obtain the opioid, use the opioid, or recover from its effects',
#  '99999-2': 'There is a persistent desire or unsuccessful efforts to cut down or control opioid use',
#  '99999-1': 'Opioids are often taken in larger amounts or over a longer period than was intended',
#  '408919008': 'Psychosocial care (regime/therapy)',
#  '698560000': 'Referral to sleep apnea clinic (procedure)',
#  '82808001': 'Sleep apnea monitoring with alarm (regime/therapy)',
#  '112790001': 'Nasal sinus endoscopy (procedure)'}

# %% [markdown]
# ## A B C D TEST (ignore this part)

# %%
import random

# Predefined groups made up of letters including at least one of A, B, or C
groups = []
for _ in range(10):  # Generate # groups
    group_size = random.randint(1, 3)  # Random group size between 1 and 10
    group = random.sample(['A', 'B', 'C','D'], group_size) #, 'D', 'E', 'F', 'G', 'H', 'I', 'J'
    groups.append(group)

print(groups)  # Print the generated groups

# Get all unique items from the groups
options = list(set(item for group in groups for item in group))

print(options)  # Print the set of all items

# %% [markdown]
# ## GROUPS

# %%
C= df['Codes'].apply(lambda x: tuple(code[0] for code in x))
groups = [[item] if isinstance(item, int) else list(item) for item in C] # for codes

D= df['Codes'].apply(lambda x: tuple(code[1] for code in x))
groups_display = [[item] if isinstance(item, int) else list(item) for item in D] # for displays

# %% [markdown]
# ## LOGVIEWER 2 + KEYBOARD ARROWS + COLORED SELECTED NODE

# %%
# Define a global variable to store the selected node
selected_node = []
PADDING = 0.1

def on_dropdown_select(event):
    global selected_groups, selected_nodes, selected_code, initial_num_nodes, selected_node
    selected_nodes = []
    selected_code = dropdown.get()  # Get the currently selected item from the dropdown menu
    selected_groups = [group for group in groups if selected_code in group]
    initial_num_nodes = len(set([item for sublist in selected_groups for item in sublist]))
    print(initial_num_nodes)  # Verify initial_num_nodes value

    selected_node = selected_code  # Store the selected node

    # Update slider range and tickinterval
    slider.config(from_=0, to=initial_num_nodes, tickinterval=max(1, initial_num_nodes))

    # Clear log text before inserting new content
    log_text.delete(1.0, tk.END)

    # Insert selected nodes and their translation
    if selected_nodes:
        log_text.insert(tk.END, "Visualized nodes and their translation:\n")
        for node in selected_nodes[::-1]:
            display_name = options_zip.get(node, "Unknown")
            log_text.insert(tk.END, "{}: {}\n".format(node, display_name))

    num_nodes_to_visualize = len(selected_nodes)
    generate_graph(canvas, selected_groups, num_nodes_to_visualize, log_text, selected_node)

    # Update the label with the display value of the selected node
    selected_display = options_zip.get(selected_code, "Unknown")
    display_label.config(text=" {}".format(selected_display))


def on_slider_move(value):
    global selected_groups, selected_nodes, selected_code, selected_node

    num_nodes_to_visualize = int(value)

    selected_groups = [group for group in groups if selected_code in group]

    # Flatten the selected groups and sort them by occurrence count
    all_selected_nodes = [node for group in selected_groups for node in group]
    node_counts = Counter(all_selected_nodes)
    sorted_nodes = sorted(node_counts, key=node_counts.get, reverse=True)

    # Select the nodes to visualize based on the slider value
    selected_nodes = sorted_nodes[:num_nodes_to_visualize]

    # Generate the graph with the selected nodes
    generate_graph(canvas, selected_groups, num_nodes_to_visualize, log_text, selected_node)


def generate_graph(canvas, selected_groups, num_nodes_to_visualize, log_text, selected_node):

    plt.clf()  # Clear current figure
    log_text.delete(1.0, tk.END)  # Clear previous logs
    

    labels = {}  

    G = nx.Graph()  # Initialize empty undirected graph
    
    # Add edges within selected groups
    for group in selected_groups:
        add_edges_within_group(G, group)
        
#     if log_text:
#         log_text.insert(tk.END, "Selected groups: {}\n".format(selected_groups))

    node_counts = Counter([node for group in selected_groups for node in group])

    sorted_nodes = sorted(node_counts, key=node_counts.get, reverse=True)
    
    selected_nodes = sorted_nodes[:num_nodes_to_visualize]
    
    subgraph = G.subgraph(selected_nodes)
    # Configure visual properties
    if len(subgraph) < 11:
        pos = nx.spring_layout(subgraph)
    else:
        pos = nx.circular_layout(subgraph)
    
    # Count occurrences of edges between nodes in selected groups
    edge_occurrences = Counter()
    edge_labels = {}
    for group in selected_groups:
        for i in range(len(group)):
            for j in range(i + 1, len(group)):
                node_pair = tuple(sorted([group[i], group[j]]))
                if node_pair not in edge_occurrences:
                    edge_occurrences[node_pair] = 0
                    edge_labels[node_pair] = f"{group[i]}-{group[j]}"
                edge_occurrences[node_pair] += 1
    
    # Calculate edge widths proportional to occurrences
    edge_widths = [edge_occurrences[tuple(sorted(edge))] for edge in subgraph.edges()]
    
    if log_text and selected_nodes:  # Check if selected_nodes is not empty
        log_text.insert(tk.END, "Visualized nodes and their translation:\n")
        for node in selected_nodes[::-1]:  # Print in reverse order
            display_name = options_zip.get(node, "Unknown")
            log_text.insert(tk.END, "{}: {}\n".format(node, display_name))
    # Print edge widths alongside corresponding node pairs
    for edge, width in zip(subgraph.edges(), edge_widths):
        node_pair = tuple(sorted(edge))
        if log_text:
            log_text.insert(tk.END, f"Edge {edge_labels[node_pair]}: {width}\n")
    
    if log_text:
        log_text.insert(tk.END, "Node occurrences: {}\n".format(node_counts))
      
   # Calculate normalization factors based on the number of nodes to visualize
    num_nodes_to_visualize = max(1, min(num_nodes_to_visualize, len(subgraph.nodes())))
    num_edges = len(subgraph.edges())
    
    if num_nodes_to_visualize > 0:
        # Calculate node size and edge width factors to fit within the desired range
        max_node_size = 20000
        min_node_size = 0
        max_edge_width = 10
        min_edge_width = 0
        
        # Calculate scaling factors if node_counts and edge_occurrences are not empty
        if node_counts:
            node_size_factor = (max_node_size - min_node_size) / max(node_counts.values())
        else:
            node_size_factor = 0
        
        if edge_occurrences:
            edge_width_factor = (max_edge_width - min_edge_width) / max(edge_occurrences.values())
        else:
            edge_width_factor = 0
    
    # Normalize node size and edge width
    node_size = [min(max(node_counts[n] * node_size_factor, min_node_size), max_node_size) for n in subgraph.nodes()]
    edge_widths = [min(max(edge_occurrences[tuple(sorted(edge))] * edge_width_factor, min_edge_width), max_edge_width) for edge in subgraph.edges()]

  
    selected_node_color = "pink"  # Choose a color for the selected node
    selected_node_linewidth = 2.0  # Choose a linewidth for the selected node

    for node in subgraph.nodes():
        if node == selected_node:  # Check if the current node is the selected node
            nx.draw_networkx_nodes(subgraph, pos, nodelist=[node], node_size=node_size_factor * node_counts[node],
                                   node_color=selected_node_color, edgecolors="k", alpha=0.4, linewidths=selected_node_linewidth)
        else:
            nx.draw_networkx_nodes(subgraph, pos, nodelist=[node], node_size=node_size_factor * node_counts[node],
                                   node_color="w", edgecolors="k", alpha=0.4, linewidths=0.5)

    if len(subgraph) > 1:
        nx.draw_networkx_edges(subgraph, pos, width=edge_widths, edge_color="black", alpha=0.4)
    
    # Draw labels on the nodes using plt.annotate
    for node, (x, y) in pos.items():
        text = labels.get(node, "")
        plt.annotate(text, (x, y), fontsize=30, ha='center', va='center')

    # Add padding to the boundaries of the figure
    xmin, xmax = plt.xlim()
    ymin, ymax = plt.ylim()
    xmargin = (xmax - xmin) * PADDING
    ymargin = (ymax - ymin) * PADDING
    plt.xlim(xmin - xmargin, xmax + xmargin)
    plt.ylim(ymin - ymargin, ymax + ymargin)
    
        # Create labels with display names and wrap text
    labels = {}
    for node in subgraph.nodes():
        if node in options_zip:
            label = options_zip[node]
            wrapped_label = '\n'.join(textwrap.wrap(label, width=15))  # Adjust width as needed
            labels[node] = wrapped_label
    
    # Draw labels on the nodes
    nx.draw_networkx_labels(subgraph, pos, labels=labels, font_size=12/math.log(num_nodes_to_visualize+1, 8),
                            font_family='Calibri', font_weight='normal')
    
     

    plt.axis("off")
    canvas.draw()


def add_edges_within_group(G, group):
    if isinstance(group, int):
        return
    for i, u in enumerate(group):
        for v in group[:i]:
            if isinstance(u, str) and isinstance(v, str):
                G.add_edge(u, v, weight=1)
            elif isinstance(u, tuple) and isinstance(v, tuple):
                for a in u:
                    for b in v:
                        G.add_edge(a, b, weight=1)

def on_arrow_key(event):
    global slider
    current_value = int(slider.get())
    if event.keysym == 'Right':
        slider.set(current_value + 1)
    elif event.keysym == 'Left':
        slider.set(current_value - 1)
        


# Create the main Tkinter window
root = tk.Tk()
root.title("Graph Visualization")

# Define the selected groups and dropdown menu
selected_groups = []
dropdown = ttk.Combobox(root, values=options)
dropdown.grid(row=0, column=0, padx=10, pady=10)
dropdown.bind("<<ComboboxSelected>>", on_dropdown_select)

# Define a label to display the value of the selected node
display_label = tk.Label(root, text="")
display_label.grid(row=0, column=1, padx=10, pady=10)

# Define the slider for selecting the number of nodes to visualize
initial_num_nodes = 0
slider = tk.Scale(root, from_=0, to=initial_num_nodes, orient=tk.HORIZONTAL, length=200, tickinterval=initial_num_nodes,
                  command=on_slider_move)  # Remove lambda and extra argument

slider.grid(row=0, column=2, padx=10, pady=10)


# Bind arrow keys to the function
root.bind('<Right>', on_arrow_key)
root.bind('<Left>', on_arrow_key)

# Create the figure and canvas for displaying the graph
fig = plt.figure(figsize=(9, 9))
canvas = FigureCanvasTkAgg(fig, master=root)
canvas.get_tk_widget().grid(row=1, column=0, padx=10, pady=10, columnspan=3)

# Create the log viewer Text widget
log_text = tk.Text(root, wrap=tk.WORD, width=40, height=20)
log_text.grid(row=1, column=3, padx=10, pady=10, sticky="nsew", columnspan=3)

# Configure grid weights to make the log viewer resizable
root.grid_rowconfigure(1, weight=1)
root.grid_columnconfigure(0, weight=1)
root.grid_columnconfigure(1, weight=1)
root.grid_columnconfigure(2, weight=1)

# Generate the initial graph with empty selected groups
generate_graph(canvas, [], 0, log_text, selected_node)

# Start the Tkinter event loop
root.mainloop()
# Out:
# 59
# 3
# 20
# 2
# 3
# 4
# 3
# 4
# 120
# 59
# 4
# 197
# 59
# 3
# 20
# 117
# 5
# 20
# 4
# 59
# 125

# %% [markdown]
# ## WRAP TEXT

# %%
def generate_graph(canvas, selected_groups, num_nodes_to_visualize, padding=0.1):
    plt.clf()  # Clear current figure
 
    G = nx.Graph()  # Initialize empty undirected graph
    
    # Add edges within selected groups
    for group in selected_groups:
        add_edges_within_group(G, group)
    
    # Count occurrences of each node in selected groups
    node_counts = Counter([node for group in selected_groups for node in group])
    
    sorted_nodes = sorted(node_counts, key=node_counts.get, reverse=True)
    
    selected_nodes = sorted_nodes[:num_nodes_to_visualize]
    subgraph = G.subgraph(selected_nodes)
    
    # Configure visual properties
    if len(subgraph) < 10:
        pos = nx.spring_layout(subgraph)
    else:
        pos = nx.circular_layout(subgraph)
    
    # Count occurrences of edges between nodes in selected groups
    edge_occurrences = Counter()
    edge_labels = {}
    for group in selected_groups:
        for i in range(len(group)):
            for j in range(i + 1, len(group)):
                node_pair = tuple(sorted([group[i], group[j]]))
                if node_pair not in edge_occurrences:
                    edge_occurrences[node_pair] = 0
                    edge_labels[node_pair] = f"{group[i]}-{group[j]}"
                edge_occurrences[node_pair] += 1
    
    # Calculate edge widths proportional to occurrences
    edge_widths = [edge_occurrences[tuple(sorted(edge))] for edge in subgraph.edges()]
    
    # Calculate normalization factors based on the number of nodes to visualize
    num_nodes_to_visualize = max(1, min(num_nodes_to_visualize, len(subgraph.nodes())))
    num_edges = len(subgraph.edges())
    
    if num_nodes_to_visualize > 0:
        node_size_factor = 5000 / num_nodes_to_visualize
    
    if num_edges > 0:
        edge_width_factor = 1 / num_edges
    
    # Normalize node size and edge width
    node_size = [node_counts[n] * node_size_factor for n in subgraph.nodes()]
    edge_widths = [edge_occurrences[tuple(sorted(edge))] * edge_width_factor for edge in subgraph.edges()]
    
    # Draw nodes and edges with normalized sizes
    nx.draw_networkx_nodes(subgraph, pos, node_size=node_size, node_color="w", edgecolors="k", linewidths=0.5)
    if len(subgraph) > 1:
        nx.draw_networkx_edges(subgraph, pos, width=edge_widths, edge_color="black", alpha=0.4)
    
    # Add padding to the boundaries of the figure
    xmin, xmax = plt.xlim()
    ymin, ymax = plt.ylim()
    xmargin = (xmax - xmin) * padding
    ymargin = (ymax - ymin) * padding
    plt.xlim(xmin - xmargin, xmax + xmargin)
    plt.ylim(ymin - ymargin, ymax + ymargin)
    
    # Create labels with display names and wrap text
    labels = {}
    for node in subgraph.nodes():
        if node in options_zip:
            label = options_zip[node]
            wrapped_label = '\n'.join(textwrap.wrap(label, width=10))  # Adjust width as needed
            labels[node] = wrapped_label
    
    # Draw labels on the nodes
    nx.draw_networkx_labels(subgraph, pos, labels=labels, font_size=20/math.log(num_nodes_to_visualize+1, 3),
                            font_family='Calibri', font_weight='normal')
    
    # Add tooltips to nodes
    cursor = mplcursors.cursor(hover=True)
    cursor.connect("add", lambda sel: sel.annotation.set_text(options_zip.get(sel.target, "")))
    
    # Add hover effect to nodes
    hover_font_size = 30
    for node, (x, y) in pos.items():
        text = labels.get(node, "")
        plt.text(x, y, text, fontsize=hover_font_size, ha='center', va='center', alpha=0.0)
        plt.text(x, y, text, fontsize=hover_font_size, ha='center', va='center', alpha=0.0, zorder=10)
    
    plt.axis("off")
    canvas.draw()



    
def on_dropdown_select(event):
    
    global selected_groups
    
    selected_code = dropdown.get()
    
    selected_groups = [group for group in groups if selected_code in group]
    print('selected_groups', selected_groups)
    
    num_nodes_to_visualize = len(set([item for sublist in selected_groups for item in sublist]))
    print('num_nodes_to_visualize', num_nodes_to_visualize)
    slider.config(from_=1, to=num_nodes_to_visualize, tickinterval=num_nodes_to_visualize-1)
    
    generate_graph(canvas, selected_groups, 1)

def add_edges_within_group(G, group):
    if isinstance(group, int):
        return
    for i, u in enumerate(group):
        for v in group[:i]:
            if isinstance(u, str) and isinstance(v, str):
                G.add_edge(u, v, weight=1)
            elif isinstance(u, tuple) and isinstance(v, tuple):
                for a in u:
                    for b in v:
                        G.add_edge(a, b, weight=1)

root = tk.Tk()
root.title("Graph Visualization")

selected_groups = []
dropdown = ttk.Combobox(root, values=options)
dropdown.grid(row=0, column=0, padx=10, pady=10)
dropdown.bind("<<ComboboxSelected>>", on_dropdown_select)

initial_num_nodes = 0
slider = tk.Scale(root, from_=0, to=initial_num_nodes, orient=tk.HORIZONTAL, length=200, tickinterval=initial_num_nodes,
                  command=lambda x: generate_graph(canvas, selected_groups, int(x)))
slider.grid(row=0, column=1, padx=10, pady=10)

fig = plt.figure(figsize=(9, 9))
canvas = FigureCanvasTkAgg(fig, master=root)
root.configure(bg='darkgrey')
canvas.get_tk_widget().grid(row=1, column=0, columnspan=2)

generate_graph(canvas, [], 0)

root.mainloop()

# %% [markdown]
# ## DISPLAY NAMES

# %%
def generate_graph(canvas, selected_groups, num_nodes_to_visualize, padding=0.1):
    
    plt.clf()  # Clear current figure
    
    # Creates the related components and their connections that will be visualized
    G = nx.Graph()  # Initialize empty undirected graph
    
    for group in selected_groups:
        add_edges_within_group(G, group)  # Add edges within group
    
    # Count occurrences of each node in selected groups
    node_counts = Counter([node for group in selected_groups for node in group])
    
    sorted_nodes = sorted(node_counts, key=node_counts.get, reverse=True)
    
    selected_nodes = sorted_nodes[:num_nodes_to_visualize]  # Related to slider value
    
    subgraph = G.subgraph(selected_nodes)  # Only with selected nodes
    
    # Configure visual properties
    if len(subgraph) < 10:
        pos = nx.spring_layout(subgraph)
    else:
        pos = nx.circular_layout(subgraph)
        
    # Count occurrences of edges between nodes in selected groups
    edge_occurrences = Counter()
    edge_labels = {}  # Store labels for each edge

    for group in selected_groups:
        for i in range(len(group)):
            for j in range(i + 1, len(group)):
                node_pair = tuple(sorted([group[i], group[j]]))  # Ensure consistent order for node pair
                if node_pair not in edge_occurrences:
                    edge_occurrences[node_pair] = 0
                    edge_labels[node_pair] = f"{group[i]}-{group[j]}"  # Store label for this edge
                edge_occurrences[node_pair] += 1
    
    # Calculate edge widths proportional to occurrences
    edge_widths = [edge_occurrences[tuple(sorted(edge))] for edge in subgraph.edges()]
    
    # Calculate normalization factors based on the number of nodes to visualize
    num_nodes_to_visualize = max(1, min(num_nodes_to_visualize, len(subgraph.nodes())))
    num_edges = len(subgraph.edges())
    
    if num_nodes_to_visualize > 0:
        node_size_factor = 5000 / num_nodes_to_visualize
    else:
        pass
    
    if num_edges > 0:
        edge_width_factor = 1 / num_edges
    else:
        pass
    
    # Normalize node size and edge width
    node_size = [node_counts[n] * node_size_factor for n in subgraph.nodes()]
    edge_widths = [edge_occurrences[tuple(sorted(edge))] * edge_width_factor for edge in subgraph.edges()]
    
    # Draw nodes and edges with normalized sizes
    nx.draw_networkx_nodes(subgraph, pos, node_size=node_size, node_color="w", edgecolors="k", linewidths=0.5)
    if len(subgraph) > 1:
        nx.draw_networkx_edges(subgraph, pos, width=edge_widths, edge_color="black", alpha=0.4)
    
    # Add padding to the boundaries of the figure
    xmin, xmax = plt.xlim()
    ymin, ymax = plt.ylim()
    xmargin = (xmax - xmin) * padding
    ymargin = (ymax - ymin) * padding
    plt.xlim(xmin - xmargin, xmax + xmargin)
    plt.ylim(ymin - ymargin, ymax + ymargin)
    
    # Create labels with display names
    labels = {node: options_zip[node] for node in subgraph.nodes() if node in options_zip}
    
    # Draw labels on the nodes
    nx.draw_networkx_labels(subgraph, pos, labels=labels, font_size=20/math.log(num_nodes_to_visualize+1, 3), font_family='Calibri', font_weight='normal')
    
    # Add tooltips to nodes
    cursor = mplcursors.cursor(hover=True)
    cursor.connect("add", lambda sel: sel.annotation.set_text(options_zip.get(sel.target, "")))
    
    plt.axis("off")
    canvas.draw()
    
def on_dropdown_select(event):
    
    global selected_groups
    
    selected_code = dropdown.get()
    
    selected_groups = [group for group in groups if selected_code in group]
    print('selected_groups', selected_groups)
    
    num_nodes_to_visualize = len(set([item for sublist in selected_groups for item in sublist]))
    print('num_nodes_to_visualize', num_nodes_to_visualize)
    slider.config(from_=1, to=num_nodes_to_visualize, tickinterval=num_nodes_to_visualize-1)
    
    generate_graph(canvas, selected_groups, 1)

def add_edges_within_group(G, group):
    if isinstance(group, int):
        return
    for i, u in enumerate(group):
        for v in group[:i]:
            if isinstance(u, str) and isinstance(v, str):
                G.add_edge(u, v, weight=1)
            elif isinstance(u, tuple) and isinstance(v, tuple):
                for a in u:
                    for b in v:
                        G.add_edge(a, b, weight=1)

root = tk.Tk()
root.title("Graph Visualization")

selected_groups = []
dropdown = ttk.Combobox(root, values=options)
dropdown.grid(row=0, column=0, padx=10, pady=10)
dropdown.bind("<<ComboboxSelected>>", on_dropdown_select)

initial_num_nodes = 0
slider = tk.Scale(root, from_=0, to=initial_num_nodes, orient=tk.HORIZONTAL, length=200, tickinterval=initial_num_nodes,
                  command=lambda x: generate_graph(canvas, selected_groups, int(x)))
slider.grid(row=0, column=1, padx=10, pady=10)

fig = plt.figure(figsize=(9, 9))
canvas = FigureCanvasTkAgg(fig, master=root)
root.configure(bg='darkgrey')
canvas.get_tk_widget().grid(row=1, column=0, columnspan=2)

generate_graph(canvas, [], 0)

root.mainloop()

# %% [markdown]
# ## CODES

# %%
def generate_graph(canvas, selected_groups, num_nodes_to_visualize,padding=0.1):
    
    plt.clf() #clear current figure
    
    
    ### Creates the related components and their connections that will be visualized
    G = nx.Graph() # initialize empty indirected graph
    
    for group in selected_groups:
        add_edges_within_group(G, group)  # Add edges within group
    

    # Count occurrences of each node in selected groups
    node_counts = Counter([node for group in selected_groups for node in group])
    print('node_occurrences', node_counts)
        
   
    sorted_nodes = sorted(node_counts, key=node_counts.get, reverse=True)
    print('sorted_nodes',sorted_nodes)
    
    selected_nodes = sorted_nodes[:num_nodes_to_visualize] # related to slider value
    print('selected_nodes',selected_nodes)
    
    subgraph = G.subgraph(selected_nodes)  # only with selected nodes

    
    
    ### Configure visual properties
    if len(subgraph) < 10:
        pos = nx.spring_layout(subgraph)
    else:
        pos = nx.circular_layout(subgraph)
        

    # Count occurrences of edges between nodes in selected groups
    edge_occurrences = Counter()
    edge_labels = {}  # Store labels for each edge

    for group in selected_groups:
        for i in range(len(group)):
            for j in range(i + 1, len(group)):
                node_pair = tuple(sorted([group[i], group[j]]))  # Ensure consistent order for node pair
                if node_pair not in edge_occurrences:
                    edge_occurrences[node_pair] = 0
                    edge_labels[node_pair] = f"{group[i]}-{group[j]}"  # Store label for this edge
                edge_occurrences[node_pair] += 1

    # Calculate edge widths proportional to occurrences
    edge_widths = [edge_occurrences[tuple(sorted(edge))] for edge in subgraph.edges()]

    # Print edge widths alongside corresponding node pairs
    for edge, width in zip(subgraph.edges(), edge_widths):
        node_pair = tuple(sorted(edge))
        print(f"Edge {edge_labels[node_pair]}: {width}")

    
    # Calculate normalization factors based on the number of nodes to visualize
    num_nodes_to_visualize = max(1, min(num_nodes_to_visualize, len(subgraph.nodes())))
    num_edges = len(subgraph.edges())

    if num_nodes_to_visualize > 0:
        node_size_factor = 5000 / num_nodes_to_visualize
    else:
        pass #node_size_factor = 1  # Set a default value to avoid division by zero

    if num_edges > 0:
        edge_width_factor = 1 / num_edges
    else:
        pass #edge_width_factor = 1  # Set a default value to avoid division by zero


    # Normalize node size and edge width
    node_size = [node_counts[n] * node_size_factor for n in subgraph.nodes()]
    edge_widths = [edge_occurrences[tuple(sorted(edge))] * edge_width_factor for edge in subgraph.edges()]

    # Draw nodes and edges with normalized sizes
    nx.draw_networkx_nodes(subgraph, pos, node_size=node_size, node_color="w", edgecolors="k", linewidths=0.5)
    if len(subgraph) > 1:
        nx.draw_networkx_edges(subgraph, pos, width=edge_widths, edge_color="black", alpha=0.4)
    
        # Add padding to the boundaries of the figure
    xmin, xmax = plt.xlim()
    ymin, ymax = plt.ylim()
    xmargin = (xmax - xmin) * padding
    ymargin = (ymax - ymin) * padding
    plt.xlim(xmin - xmargin, xmax + xmargin)
    plt.ylim(ymin - ymargin, ymax + ymargin)
    
    nx.draw_networkx_labels(subgraph, pos, labels={node: str(node) for node in subgraph.nodes()}, font_size=20/math.log(num_nodes_to_visualize+1,3), font_family='Calibri', font_weight='normal')

    plt.axis("off")
    canvas.draw()
    


def on_dropdown_select(event):
    
    global selected_groups
    
    selected_code = dropdown.get()
    
    selected_groups = [group for group in groups if selected_code in group]
    print('selected_groups', selected_groups)
    
    num_nodes_to_visualize = len(set([item for sublist in selected_groups for item in sublist]))
    print('num_nodes_to_visualize', num_nodes_to_visualize)
    slider.config(from_=1, to=num_nodes_to_visualize, tickinterval=num_nodes_to_visualize-1)
    
    generate_graph(canvas, selected_groups, 1)



def add_edges_within_group(G, group):
    if isinstance(group, int):
        return
    for i, u in enumerate(group):
        for v in group[:i]:
            if isinstance(u, str) and isinstance(v, str):
                G.add_edge(u, v, weight=1)
            elif isinstance(u, tuple) and isinstance(v, tuple):
                for a in u:
                    for b in v:
                        G.add_edge(a, b, weight=1)

root = tk.Tk()
root.title("Graph Visualization")

selected_groups = []
dropdown = ttk.Combobox(root, values=options)
dropdown.grid(row=0, column=0, padx=10, pady=10)
dropdown.bind("<<ComboboxSelected>>", on_dropdown_select)

initial_num_nodes = 0
slider = tk.Scale(root, from_=0, to=initial_num_nodes, orient=tk.HORIZONTAL, length=200, tickinterval=initial_num_nodes,
                  command=lambda x: generate_graph(canvas, selected_groups, int(x)))
slider.grid(row=0, column=1, padx=10, pady=10)


fig = plt.figure(figsize=(9, 9))
#fig.set_facecolor((0.2, 0.2, 0.2))  # RGB values for a darker grey
canvas = FigureCanvasTkAgg(fig, master=root)
#root.attributes('-alpha', 0.8)  # Adjust alpha value as needed (0.0 to 1.0)
root.configure(bg='darkgrey')
canvas.get_tk_widget().grid(row=1, column=0, columnspan=2)

generate_graph(canvas, [], 0)

root.mainloop()

# %%
import networkx as nx

# Create a graph
G = nx.Graph()

# Add some nodes
G.add_nodes_from([1, 2, 3, 4])

# Add some edges
G.add_edges_from([(1, 2), (1, 3), (2, 3), (3, 4)])

# Create a subgraph
subgraph = G.subgraph([1, 2, 3])

# Get the degree of node 1 in the subgraph
degree_of_node_1 = subgraph.degree(1)

print("Degree of node 1 in the subgraph:", degree_of_node_1)

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a graph
G = nx.Graph()

# Add some nodes
G.add_nodes_from([1, 2, 3, 4])

# Add some edges
G.add_edges_from([(1, 2), (1, 3), (2, 3), (3, 4)])

# Create a subgraph
subgraph = G.subgraph([1, 2, 3,4])

# Plot the subgraph
nx.draw(subgraph, with_labels=True, node_color='skyblue', node_size=500, font_size=12, font_color='black')
plt.show()

# %%
subgraph.degree(4)

# %%
import matplotlib.pyplot as plt
import networkx as nx
from mpl_toolkits.mplot3d import Axes3D

# Define a function to plot glanzing steel edges with a 3D effect
def plot_glanzing_steel_edges(ax, G, pos, depth=0.1):
    edges = []
    for edge in G.edges():
        x = [pos[edge[0]][0], pos[edge[1]][0]]
        y = [pos[edge[0]][1], pos[edge[1]][1]]
        z = [depth, depth]
        edges.append(list(zip(x, y, z)))
    for edge in edges:
        ax.plot(*edge, color='silver', linewidth=2)

# Create a graph
G = nx.Graph()

# Add nodes
G.add_nodes_from([1, 2, 3, 4, 5, 6])

# Add edges
G.add_edges_from([(1, 2), (1, 3), (2, 3), (3, 4), (4, 5), (4, 6), (5, 6)])

# Specify node positions in 2D space
pos = {1: (1, 1), 2: (2, 2), 3: (3, 3), 4: (4, 4), 5: (5, 5), 6: (6, 6)}

# Draw the graph
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

# Call function to plot glanzing steel edges with a 3D effect
plot_glanzing_steel_edges(ax, G, pos)

# Set axis labels
ax.set_xlabel('X', fontsize=12)
ax.set_ylabel('Y', fontsize=12)
ax.set_zlabel('Depth', fontsize=12)

# Set title
plt.title('Glanzing Steel Edges', fontsize=14)

# Show the graph
plt.show()

# %%
    
def update_dropdown_list():
    global codes, displays
    
    selected_code = code_var.get()
    selected_display = display_var.get()
    
    if selected_code and selected_display:
        dropdown['values'] = [f"{code} ({display})" for code, display in zip(codes, displays)]
    elif selected_code:
        dropdown['values'] = codes
    elif selected_display:
        dropdown['values'] = displays
    else:
        dropdown['values'] = []

def on_dropdown_select(event):
    global selected_groups
    
    selected_item = dropdown.get()
    
    if code_var.get() and display_var.get():
        selected_item = selected_item.split(" (")[0]
    
    selected_groups = [group for group in groups if selected_item in group]
    print('selected_groups', selected_groups)
    
    num_nodes_to_visualize = len(set([item for sublist in selected_groups for item in sublist]))
    print('num_nodes_to_visualize', num_nodes_to_visualize)
    slider.config(from_=1, to=num_nodes_to_visualize, tickinterval=num_nodes_to_visualize-1)
    
    # Determine whether to use display names
    use_display = display_var.get()
    
    generate_graph(canvas, selected_groups, 1, use_display)


def add_edges_within_group(G, group):
    if isinstance(group, int):
        return
    for i, u in enumerate(group):
        for v in group[:i]:
            if isinstance(u, str) and isinstance(v, str):
                G.add_edge(u, v, weight=1)
            elif isinstance(u, tuple) and isinstance(v, tuple):
                for a in u:
                    for b in v:
                        G.add_edge(a, b, weight=1)

def generate_graph(canvas, selected_groups, num_nodes_to_visualize, use_display=False, padding=0.1):
    plt.clf()  # Clear current figure

    # Creates the related components and their connections that will be visualized
    G = nx.Graph()  # Initialize empty undirected graph
    
    for group in selected_groups:
        add_edges_within_group(G, group)  # Add edges within group

    # Count occurrences of each node in selected groups
    node_counts = Counter([node for group in selected_groups for node in group])

    sorted_nodes = sorted(node_counts, key=node_counts.get, reverse=True)

    selected_nodes = sorted_nodes[:num_nodes_to_visualize]  # Related to slider value

    subgraph = G.subgraph(selected_nodes)  # Only with selected nodes

    # Configure visual properties
    if len(subgraph) < 10:
        pos = nx.spring_layout(subgraph)
    else:
        pos = nx.circular_layout(subgraph)

    # Count occurrences of edges between nodes in selected groups
    edge_occurrences = Counter()
    edge_labels = {}  # Store labels for each edge

    for group in selected_groups:
        for i in range(len(group)):
            for j in range(i + 1, len(group)):
                node_pair = tuple(sorted([group[i], group[j]]))  # Ensure consistent order for node pair
                if node_pair not in edge_occurrences:
                    edge_occurrences[node_pair] = 0
                    edge_labels[node_pair] = f"{group[i]}-{group[j]}"  # Store label for this edge
                edge_occurrences[node_pair] += 1

    # Calculate edge widths proportional to occurrences
    edge_widths = [edge_occurrences[tuple(sorted(edge))] for edge in subgraph.edges()]

    # Calculate normalization factors based on the number of nodes to visualize
    num_nodes_to_visualize = max(1, min(num_nodes_to_visualize, len(subgraph.nodes())))
    num_edges = len(subgraph.edges())

    if num_nodes_to_visualize > 0:
        node_size_factor = 500 / num_nodes_to_visualize
    else:
        pass #node_size_factor = 1  # Set a default value to avoid division by zero

    if num_edges > 0:
        edge_width_factor = 1 / num_edges
    else:
        pass #edge_width_factor = 1  # Set a default value to avoid division by zero


    # Normalize node size and edge width
    node_size = [node_counts[n] * node_size_factor for n in subgraph.nodes()]
    edge_widths = [edge_occurrences[tuple(sorted(edge))] * edge_width_factor for edge in subgraph.edges()]

    # Draw nodes and edges with normalized sizes
    nx.draw_networkx_nodes(subgraph, pos, node_size=node_size, node_color="w", edgecolors="k", linewidths=0.5)
    if len(subgraph) > 1:
        nx.draw_networkx_edges(subgraph, pos, width=edge_widths, edge_color="black", alpha=0.4)
    
    # Change labels to display values if use_display is True
    labels = {node: str(node) for node in subgraph.nodes()}
    if use_display:
        for node in labels:
            if node in display_mapping:
                labels[node] = display_mapping[node]
    
    nx.draw_networkx_labels(subgraph, pos, labels=labels, font_size=50/math.log(num_nodes_to_visualize+1,3), font_family='Calibri', font_weight='normal')

    # Add padding to the boundaries of the figure
    xmin, xmax = plt.xlim()
    ymin, ymax = plt.ylim()
    xmargin = (xmax - xmin) * padding
    ymargin = (ymax - ymin) * padding
    plt.xlim(xmin - xmargin, xmax + xmargin)
    plt.ylim(ymin - ymargin, ymax + ymargin)

    plt.axis("off")
    canvas.draw()
    
    

def on_display_checkbox_click():
    global display_var, selected_groups
    use_display = display_var.get()
    generate_graph(canvas, selected_groups, 1, use_display)


    
    
root = tk.Tk()
root.title("FHIR")

# Checkbox variables
code_var = tk.BooleanVar()
display_var = tk.BooleanVar()

# Checkboxes
code_checkbox = tk.Checkbutton(root, text="Code", variable=code_var, command=update_dropdown_list)
code_checkbox.grid(row=0, column=0, padx=10, pady=10)

display_checkbox = tk.Checkbutton(root, text="Display", variable=display_var, command=update_dropdown_list)
display_checkbox.grid(row=0, column=1, padx=10, pady=10)

# Update the checkbox command
display_checkbox = tk.Checkbutton(root, text="Display", variable=display_var, command=on_display_checkbox_click)

# Dropdown list
dropdown = ttk.Combobox(root)
dropdown.grid(row=1, column=0, columnspan=2, padx=10, pady=10)
dropdown.bind("<<ComboboxSelected>>", on_dropdown_select)

# Slider
initial_num_nodes = 0
slider = tk.Scale(root, from_=0, to=initial_num_nodes, orient=tk.HORIZONTAL, length=200, tickinterval=initial_num_nodes,
                  command=lambda x: generate_graph(canvas, selected_groups, int(x)))
slider.grid(row=2, column=0, columnspan=2, padx=10, pady=10)

# Figure canvas
fig = plt.figure(figsize=(9, 9))
canvas = FigureCanvasTkAgg(fig, master=root)
canvas.get_tk_widget().grid(row=3, column=0, columnspan=2, padx=10, pady=10)

# Initialize selected groups
selected_groups = []

# Generate initial graph
generate_graph(canvas, [], 0)

# Start GUI main loop
root.mainloop()
